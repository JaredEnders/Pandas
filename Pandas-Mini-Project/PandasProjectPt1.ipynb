# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
coder_df = pd.read_csv(csv_path)
coder_df.head()
# Out:
# C:\Users\jared\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %%
# Inspect all columns
coder_df.count()
# Out:
# Age                     13613
# AttendedBootcamp        15380
# BootcampFinish            933
# BootcampFullJobAfter      635
# BootcampLoanYesNo         934
#                         ...
# ResourceW3Schools         121
# ResourceYouTube           121
# SchoolDegree            13679
# SchoolMajor              8450
# StudentDebtOwe           3514
# Length: 113, dtype: int64

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_coder = coder_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_coder.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
replace_list = ["HasChildren", "AttendedBootcamp", "BootcampFinish", "BootcampLoanYesNo", "BootcampRecommend", "BootcampFullJobAfter", "CodeEventBootcamp"]

reduced_coder[replace_list] = reduced_coder[replace_list].replace({0: "No", 1: "Yes"})
reduced_coder.head()
# Out:
# C:\Users\jared\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend  ChildrenNumber  \
# 0               NaN                 NaN               NaN             NaN
# ...

# %%
# Calculate total number of respondents in survey
totalrespondents = len(reduced_coder)
totalrespondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended = reduced_coder.loc[reduced_coder["AttendedBootcamp"] == "Yes"]
attended.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend  ChildrenNumber  \
# 93                 No                 NaN                No             NaN
# 97                 No             45000.0                No             NaN
# 130               Yes             75000.0               Yes             3.0
# 159                No                 NaN                No             NaN
# 188               Yes                 NaN                No             NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# ...

# %%
# Calculate average age of attendees
averageage = attended["Age"].mean()
print(averageage)
# Calculate how many people attended a bootcamp
attendance = attended["AttendedBootcamp"].count()
print(attendance)
# Calculate how many attendees hold degrees
degrees = ["bachelor's degree", "master's degree (non-professional)", "professional degree (MBA, MD, JD, etc.)", "associate's degree", "Ph.D."]
collegedegrees = attended["SchoolDegree"].isin(degrees).sum()
print(collegedegrees)
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
attended["Gender"].value_counts()
# Male count
males = attended["Gender"].value_counts()['male']
print(males)
# Female count
females = attended["Gender"].value_counts()['female']
print(females)
# Non-binary count
nb = ["genderqueer", "trans", "agender"]
nonbinary = attended["Gender"].isin(nb).sum()
print(nonbinary) 
# Calculate percentage of respondents who attended a bootcamp
percentattend = round((attendance / totalrespondents) * 100,2)
print(percentattend)
# Calculate percentage of respondents belonging to each gender
genderresp = attended["Gender"].notna().sum()
percmales = round((males / genderresp) * 100,2)
percfemales = round((females / genderresp) * 100,2)
percnb = round((nonbinary / genderresp) * 100,2)
print(percmales)
print(percfemales)
print(percnb)
# Calculate percentage of attendees with a school degree
percdegree = round((collegedegrees / attendance) * 100,2)
print(percdegree) 
# Calculate average post-bootcamp salary
avgsalary = round(attended["BootcampPostSalary"].mean(),0)
print(avgsalary)
# Out:
# 31.066014669926652
# 953
# 637
# 496
# 326
# 11
# 6.1
# 59.54
# 39.14
# 1.32
# 66.84
# 63741.0

# %%
# Create a new table consolodating above calculations
table_df = {"Total Number of People Surveyed": [totalrespondents], "Total Attendees": [attendance], "Average Age of Attendee": [averageage], "Attendees with Degree": [collegedegrees], "Percent of Attendees with Degree": [percdegree], "Male Attendance": [males], "Percentage of Male Attendees": [percmales], "Female Attendance": [females], "Percentage of Female Attendance": [percfemales], "Non-binary Attendance": [nonbinary], "Non-binary Percentage of Attendees": [percnb], "Average Salary Post-Bootcamp": [avgsalary]}
pd.DataFrame(table_df)
# Out:
#    Total Number of People Surveyed  Total Attendees  Average Age of Attendee  \
# 0                            15620              953                31.066015
#
#    Attendees with Degree  Percent of Attendees with Degree  Male Attendance  \
# 0                    637                             66.84              496
#
#    Percentage of Male Attendees  Female Attendance  \
# 0                         59.54                326
#
#    Percentage of Female Attendance  Non-binary Attendance  \
# 0                            39.14                     11
#
#    Non-binary Percentage of Attendees  Average Salary Post-Bootcamp
# 0                                1.32                       63741.0

# %%
# Improve formatting before outputting spreadsheet
def as_currency(amount):
        return '${:,.2f}'.format(amount)
def as_percent(amount):
    return "{0:.2f}%".format(amount)

table_df = {"Total Number of People Surveyed": [totalrespondents], "Total Attendees": [attendance], "Average Age of Attendee": [averageage], "Attendees with Degree": [collegedegrees], "Percent of Attendees with Degree": as_percent(percdegree), "Male Attendance": [males], "Percentage of Male Attendees": as_percent(percmales), "Female Attendance": [females], "Percentage of Female Attendance": as_percent(percfemales), "Non-binary Attendance": [nonbinary], "Non-binary Percentage of Attendees": as_percent(percnb), "Average Salary Post-Bootcamp": as_currency(avgsalary)}
pd.DataFrame(table_df)
# Out:
#    Total Number of People Surveyed  Total Attendees  Average Age of Attendee  \
# 0                            15620              953                31.066015
#
#    Attendees with Degree Percent of Attendees with Degree  Male Attendance  \
# 0                    637                           66.84%              496
#
#   Percentage of Male Attendees  Female Attendance  \
# 0                       59.54%                326
#
#   Percentage of Female Attendance  Non-binary Attendance  \
# 0                          39.14%                     11
#
#   Non-binary Percentage of Attendees Average Salary Post-Bootcamp
# 0                              1.32%                   $63,741.00

# %%
# Export to Excel
PandasProjectDataPt1 = pd.DataFrame(table_df)
PandasProjectDataPt1.to_excel("/Users/jared/Pandas/Pandas-Mini-Project/PandasDataPt1.xlsx", index=False)
