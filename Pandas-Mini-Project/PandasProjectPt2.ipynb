# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
coder_df = pd.read_csv(csv_path, encoding= 'iso-8859-1', low_memory=False)
coder_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_coder = coder_df.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_coder.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
replace_list = ["HasChildren", "AttendedBootcamp", "BootcampFinish", "BootcampLoanYesNo", "BootcampRecommend", "BootcampFullJobAfter", "CodeEventBootcamp"]

reduced_coder[replace_list] = reduced_coder[replace_list].replace({0: "No", 1: "Yes"})
reduced_coder.head()
# Out:
# C:\Users\jared\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended = reduced_coder.loc[reduced_coder["AttendedBootcamp"] == "Yes"]
attended
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo              BootcampName  BootcampPostSalary  \
# 93                   No            Codify Academy                 NaN
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
difbootcamp = pd.DataFrame(coder_df["BootcampName"].value_counts())
difbootcamp.reset_index(inplace=True)
difbootcamp.columns = ["BootcampName", "Number of Attendees"]
difbootcamp.head()
# Out:
#             BootcampName  Number of Attendees
# 0       General Assembly                   90
# 1        Flatiron School                   54
# 2           Dev Bootcamp                   48
# 3          The Iron Yard                   40
# 4  Prime Digital Academy                   30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommended_df = attended.replace({"Yes": 1, "No": 0})
recommended_df = pd.DataFrame(coder_df.groupby("BootcampName")["BootcampRecommend"].sum())
recommended_df.reset_index(inplace=True)
recommended_df.columns = ["BootcampName", "Number of Recommenders"]
recommended_df
# Out:
#               BootcampName  Number of Recommenders
# 0               10x.org.il                     3.0
# 1           4Geeks Academy                     4.0
# 2                 AcadGild                     2.0
# 3      Academia de CÃ³digo                     4.0
# 4    Academic Work Academy                     0.0
# ..                     ...                     ...
# 123                Wyncode                     3.0
# 124    Zip Code Wilmington                     1.0
# 125                  codeU                     1.0
# 126            devCodeCamp                     4.0
# 127             tradecraft                     1.0
#
# [128 rows x 2 columns]

# %%
# Merge the two created data frames on the name of the bootcamp
merge_df = pd.merge(difbootcamp, recommended_df, on= "BootcampName")
merge_df
# Out:
#               BootcampName  Number of Attendees  Number of Recommenders
# 0         General Assembly                   90                    70.0
# 1          Flatiron School                   54                    50.0
# 2             Dev Bootcamp                   48                    41.0
# 3            The Iron Yard                   40                    31.0
# 4    Prime Digital Academy                   30                    25.0
# ..                     ...                  ...                     ...
# 123       CodeCraft School                    1                     1.0
# 124         Base10 Academy                    1                     1.0
# 125          Claim Academy                    1                     1.0
# 126               Alphappl                    1                     0.0
# 127          Coder Foundry                    1                     1.0
#
# [128 rows x 3 columns]

# %%
# Calculate percentage of each bootcamp's students who are recommenders
merge_df["Percentage of People Recommended"] = merge_df["Number of Recommenders"] / merge_df["Number of Attendees"] *100
merge_df["Percentage of People Recommended"] = merge_df["Percentage of People Recommended"].map("{0:,.2f}%".format)
merge_df
# Out:
#               BootcampName  Number of Attendees  Number of Recommenders  \
# 0         General Assembly                   90                    70.0
# 1          Flatiron School                   54                    50.0
# 2             Dev Bootcamp                   48                    41.0
# 3            The Iron Yard                   40                    31.0
# 4    Prime Digital Academy                   30                    25.0
# ..                     ...                  ...                     ...
# 123       CodeCraft School                    1                     1.0
# 124         Base10 Academy                    1                     1.0
# 125          Claim Academy                    1                     1.0
# 126               Alphappl                    1                     0.0
# 127          Coder Foundry                    1                     1.0
#
#     Percentage of People Recommended
# 0                             77.78%
# ...

# %%
# Export to excel and remove index
PandasProjectDataPt2 = pd.DataFrame(merge_df)
PandasProjectDataPt2.to_excel("/Users/jared/Pandas/Pandas-Mini-Project/PandasDataPt2.xlsx", index=False)
